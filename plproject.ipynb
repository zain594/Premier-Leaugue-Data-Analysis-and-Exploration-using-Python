# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('D:\\Users\\DELL\\Downloads\\results.csv\\results.csv\\')

# %%
df.head()
# Out:
#           home_team         away_team  home_goals  away_goals result  \
# 0  Sheffield United         Liverpool         1.0         1.0      D
# 1           Arsenal       Aston Villa         1.0         1.0      D
# 2           Everton           Watford         2.0         1.0      H
# 3  Newcastle United    Wigan Athletic         2.0         1.0      H
# 4        Portsmouth  Blackburn Rovers         3.0         0.0      H
#
#       season
# 0  2006-2007
# 1  2006-2007
# 2  2006-2007
# 3  2006-2007
# 4  2006-2007

# %%
#to check if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# home_team - 0%
# away_team - 0%
# home_goals - 0%
# away_goals - 0%
# result - 0%
# season - 0%

# %%
#data types of our columns
print(df.dtypes)
# Out:
# home_team      object
# away_team      object
# home_goals    float64
# away_goals    float64
# result         object
# season         object
# dtype: object

# %%
df2 = df.sort_values(by = ['home_goals'], inplace = False, ascending = False)
df2
# Out:
#               home_team        away_team  home_goals  away_goals result  \
# 1265  Tottenham Hotspur   Wigan Athletic         9.0         1.0      H
# 1514            Chelsea   Wigan Athletic         8.0         0.0      H
# 1928  Manchester United          Arsenal         8.0         2.0      H
# 3116        Southampton       Sunderland         8.0         0.0      H
# 754       Middlesbrough  Manchester City         8.0         1.0      H
# ...                 ...              ...         ...         ...    ...
# 1490          Hull City       Sunderland         0.0         1.0      A
# 1493            Arsenal  Manchester City         0.0         0.0      D
# 1495            Burnley        Liverpool         0.0         4.0      A
# 1501         Stoke City          Everton         0.0         0.0      D
# 2280            Arsenal       Sunderland         0.0         0.0      D
#
#          season
# 1265  2009-2010
# 1514  2009-2010
# 1928  2011-2012
# 3116  2014-2015
# ...

# %%
#df3 = df.sort_values(by = ['away_goals'], inplace = False, ascending = False)
#df3
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4173          Hull City  Tottenham Hotspur         1.0         7.0      A
# 1986  Manchester United    Manchester City         1.0         6.0      A
# 4169     Leicester City  Tottenham Hotspur         1.0         6.0      A
# 4225            Watford    Manchester City         0.0         6.0      A
# 2229       Norwich City    Manchester City         1.0         6.0      A
# ...                 ...                ...         ...         ...    ...
# 1290    Birmingham City    West Ham United         1.0         0.0      H
# 1294          Hull City   Blackburn Rovers         0.0         0.0      D
# 3144    West Ham United        Aston Villa         0.0         0.0      D
# 3143        Southampton     Leicester City         2.0         0.0      H
# 2280            Arsenal         Sunderland         0.0         0.0      D
#
#          season
# 4173  2016-2017
# 1986  2011-2012
# 4169  2016-2017
# ...

# %%
sns.regplot(x='home_goals', y='away_goals', data=df2, scatter_kws={"color":"black"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='home_goals', ylabel='away_goals'>

# %%
df2.columns
# Out:
# Index(['home_team', 'away_team', 'home_goals', 'away_goals', 'result',
#        'season'],
#       dtype='object')

# %%
df2.season.unique()
# Out:
# array(['2009-2010', '2011-2012', '2014-2015', '2007-2008', '2012-2013',
#        '2013-2014', '2017-2018', '2010-2011', '2016-2017', '2006-2007',
#        '2015-2016', '2008-2009'], dtype=object)

# %%
df2_data_list = ['2016-2017']

# %%
df3 = df2[df2.season.isin(df2_data_list)]
df3
# Out:
#             home_team             away_team  home_goals  away_goals result  \
# 4032          Everton       AFC Bournemouth         6.0         3.0      H
# 3872  AFC Bournemouth             Hull City         6.0         1.0      H
# 3907        Liverpool               Watford         6.0         1.0      H
# 4145  Manchester City        Crystal Palace         5.0         0.0      H
# 4172          Chelsea            Sunderland         5.0         1.0      H
# ...               ...                   ...         ...         ...    ...
# 3867   Leicester City           Southampton         0.0         0.0      D
# 3862        Hull City               Chelsea         0.0         2.0      A
# 3813     Swansea City             Hull City         0.0         2.0      A
# 3802   Crystal Palace  West Bromwich Albion         0.0         1.0      A
# 3801          Burnley          Swansea City         0.0         1.0      A
#
#          season
# 4032  2016-2017
# 3872  2016-2017
# ...

# %%
df2_data_list = ['2017-2018']

# %%
df4= df2[df2.season.isin(df2_data_list)]
df4
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4253    Manchester City         Stoke City         7.0         2.0      H
# 4445    Manchester City     Leicester City         5.0         1.0      H
# 4233    Manchester City     Crystal Palace         5.0         0.0      H
# 4377          Liverpool       Swansea City         5.0         0.0      H
# 4381            Chelsea         Stoke City         5.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4423            Chelsea    AFC Bournemouth         0.0         3.0      A
# 4349    West Ham United            Arsenal         0.0         0.0      D
# 4422  Huddersfield Town          Liverpool         0.0         3.0      A
# 4215        Southampton            Watford         0.0         2.0      A
# 4213            Everton  Tottenham Hotspur         0.0         3.0      A
#
#          season
# 4253  2017-2018
# 4445  2017-2018
# 4233  2017-2018
# ...

# %%
df4.columns
# Out:
# Index(['home_team', 'away_team', 'home_goals', 'away_goals', 'result',
#        'season'],
#       dtype='object')

# %%
df4.home_team.unique
# Out:
# <bound method Series.unique of 4253      Manchester City
# 4445      Manchester City
# 4233      Manchester City
# 4377            Liverpool
# 4381              Chelsea
#               ...
# 4423              Chelsea
# 4349      West Ham United
# 4422    Huddersfield Town
# 4215          Southampton
# 4213              Everton
# Name: home_team, Length: 380, dtype: object>

# %%
df4_data_list = ['Manchester United']

# %%
df5= df4[df4.home_team.isin(df4_data_list)]
df5
# Out:
#               home_team                 away_team  home_goals  away_goals  \
# 4242  Manchester United            Crystal Palace         4.0         0.0
# 4297  Manchester United          Newcastle United         4.0         1.0
# 4229  Manchester United                   Everton         4.0         0.0
# 4189  Manchester United           West Ham United         4.0         0.0
# 4409  Manchester United                Stoke City         3.0         0.0
# 4374  Manchester United                   Burnley         2.0         2.0
# 4486  Manchester United              Swansea City         2.0         0.0
# 4532  Manchester United                   Arsenal         2.0         1.0
# 4434  Manchester United         Huddersfield Town         2.0         0.0
# 4458  Manchester United                   Chelsea         2.0         1.0
# 4470  Manchester United                 Liverpool         2.0         1.0
# 4205  Manchester United            Leicester City         2.0         0.0
# ...

# %%
df5
# Out:
#               home_team                 away_team  home_goals  away_goals  \
# 4242  Manchester United            Crystal Palace         4.0         0.0
# 4297  Manchester United          Newcastle United         4.0         1.0
# 4229  Manchester United                   Everton         4.0         0.0
# 4189  Manchester United           West Ham United         4.0         0.0
# 4409  Manchester United                Stoke City         3.0         0.0
# 4374  Manchester United                   Burnley         2.0         2.0
# 4486  Manchester United              Swansea City         2.0         0.0
# 4532  Manchester United                   Arsenal         2.0         1.0
# 4434  Manchester United         Huddersfield Town         2.0         0.0
# 4458  Manchester United                   Chelsea         2.0         1.0
# 4470  Manchester United                 Liverpool         2.0         1.0
# 4205  Manchester United            Leicester City         2.0         0.0
# ...

# %%
df5.rename(columns= {'home_team':'MU','home_goals':'MU_home_goals','away_goals':'MU_away_goals'}, inplace = True)
df5
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14728\514934756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.rename(columns= {'home_team':'MU','home_goals':'MU_home_goals','away_goals':'MU_away_goals'}, inplace = True)
#                      MU                 away_team  MU_home_goals  \
# 4242  Manchester United            Crystal Palace            4.0
# 4297  Manchester United          Newcastle United            4.0
# 4229  Manchester United                   Everton            4.0
# 4189  Manchester United           West Ham United            4.0
# 4409  Manchester United                Stoke City            3.0
# 4374  Manchester United                   Burnley            2.0
# 4486  Manchester United              Swansea City            2.0
# ...

# %%
df6=df5.drop(['away_team', 'result'], axis = 1)

# %%
df7= df4[df4.home_team.isin(df4_data_list)]
df7
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4253    Manchester City         Stoke City         7.0         2.0      H
# 4445    Manchester City     Leicester City         5.0         1.0      H
# 4233    Manchester City     Crystal Palace         5.0         0.0      H
# 4377          Liverpool       Swansea City         5.0         0.0      H
# 4381            Chelsea         Stoke City         5.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4423            Chelsea    AFC Bournemouth         0.0         3.0      A
# 4349    West Ham United            Arsenal         0.0         0.0      D
# 4422  Huddersfield Town          Liverpool         0.0         3.0      A
# 4215        Southampton            Watford         0.0         2.0      A
# 4213            Everton  Tottenham Hotspur         0.0         3.0      A
#
#          season
# 4253  2017-2018
# 4445  2017-2018
# 4233  2017-2018
# ...

# %%
df8= df7[df7.home_team.isin(df7_data_list)]
df8
# Out:
#       home_team                 away_team  home_goals  away_goals result  \
# 4377  Liverpool              Swansea City         5.0         0.0      H
# 4483  Liverpool                   Watford         5.0         0.0      H
# 4208  Liverpool                   Arsenal         4.0         0.0      H
# 4408  Liverpool           Manchester City         4.0         3.0      H
# 4553  Liverpool  Brighton and Hove Albion         4.0         0.0      H
# 4454  Liverpool           West Ham United         4.0         1.0      H
# 4295  Liverpool               Southampton         3.0         0.0      H
# 4273  Liverpool         Huddersfield Town         3.0         0.0      H
# 4509  Liverpool           AFC Bournemouth         3.0         0.0      H
# 4383  Liverpool            Leicester City         2.0         1.0      H
# 4438  Liverpool         Tottenham Hotspur         2.0         2.0      D
# 4466  Liverpool          Newcastle United         2.0         0.0      H
# ...

# %%
df8.rename(columns= {'home_team':'LIV','home_goals':'LIV_home_goals','away_goals':'LIV_away_goals'}, inplace = True)
df8
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14728\1756970877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8.rename(columns= {'home_team':'LIV','home_goals':'LIV_home_goals','away_goals':'LIV_away_goals'}, inplace = True)
#             LIV                 away_team  LIV_home_goals  LIV_away_goals  \
# 4377  Liverpool              Swansea City             5.0             0.0
# 4483  Liverpool                   Watford             5.0             0.0
# 4208  Liverpool                   Arsenal             4.0             0.0
# 4408  Liverpool           Manchester City             4.0             3.0
# 4553  Liverpool  Brighton and Hove Albion             4.0             0.0
# 4454  Liverpool           West Ham United             4.0             1.0
# ...

# %%
df9=df8.drop(['away_team', 'result'], axis = 1)
df9
# Out:
#             LIV  LIV_home_goals  LIV_away_goals     season
# 4377  Liverpool             5.0             0.0  2017-2018
# 4483  Liverpool             5.0             0.0  2017-2018
# 4208  Liverpool             4.0             0.0  2017-2018
# 4408  Liverpool             4.0             3.0  2017-2018
# 4553  Liverpool             4.0             0.0  2017-2018
# 4454  Liverpool             4.0             1.0  2017-2018
# 4295  Liverpool             3.0             0.0  2017-2018
# 4273  Liverpool             3.0             0.0  2017-2018
# 4509  Liverpool             3.0             0.0  2017-2018
# 4383  Liverpool             2.0             1.0  2017-2018
# 4438  Liverpool             2.0             2.0  2017-2018
# 4466  Liverpool             2.0             0.0  2017-2018
# 4306  Liverpool             1.0             1.0  2017-2018
# 4338  Liverpool             1.0             1.0  2017-2018
# 4194  Liverpool             1.0             0.0  2017-2018
# ...

# %%
sns.regplot(x='LIV_home_goals', y='LIV_away_goals', data=df9, scatter_kws={"color":"black"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='LIV_home_goals', ylabel='LIV_away_goals'>

# %%
df6
# Out:
#                      MU  MU_home_goals  MU_away_goals     season
# 4242  Manchester United            4.0            0.0  2017-2018
# 4297  Manchester United            4.0            1.0  2017-2018
# 4229  Manchester United            4.0            0.0  2017-2018
# 4189  Manchester United            4.0            0.0  2017-2018
# 4409  Manchester United            3.0            0.0  2017-2018
# 4374  Manchester United            2.0            2.0  2017-2018
# 4486  Manchester United            2.0            0.0  2017-2018
# 4532  Manchester United            2.0            1.0  2017-2018
# 4434  Manchester United            2.0            0.0  2017-2018
# 4458  Manchester United            2.0            1.0  2017-2018
# 4470  Manchester United            2.0            1.0  2017-2018
# 4205  Manchester United            2.0            0.0  2017-2018
# 4554  Manchester United            1.0            0.0  2017-2018
# ...

# %%
sns.regplot(x='MU_home_goals', y='MU_away_goals', data=df6, scatter_kws={"color":"black"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='MU_home_goals', ylabel='MU_away_goals'>

# %%
df10 = df6.merge(df9, how='right')
df10
# Out:
#                     MU  MU_home_goals  MU_away_goals     season        LIV  \
# 0    Manchester United            4.0            0.0  2017-2018  Liverpool
# 1    Manchester United            4.0            1.0  2017-2018  Liverpool
# 2    Manchester United            4.0            0.0  2017-2018  Liverpool
# 3    Manchester United            4.0            0.0  2017-2018  Liverpool
# 4    Manchester United            3.0            0.0  2017-2018  Liverpool
# 5    Manchester United            2.0            2.0  2017-2018  Liverpool
# 6    Manchester United            2.0            0.0  2017-2018  Liverpool
# 7    Manchester United            2.0            1.0  2017-2018  Liverpool
# 8    Manchester United            2.0            0.0  2017-2018  Liverpool
# 9    Manchester United            2.0            1.0  2017-2018  Liverpool
# 10   Manchester United            2.0            1.0  2017-2018  Liverpool
# ...

# %%
sns.regplot(x='MU_home_goals', y='LIV_home_goals', data=df10, scatter_kws={"color":"black"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='MU_home_goals', ylabel='LIV_home_goals'>

# %%
sns.regplot(x='MU_away_goals', y='LIV_away_goals', data=df10, scatter_kws={"color":"black"}, line_kws={"color":"green"})
# Out:
# <AxesSubplot:xlabel='MU_away_goals', ylabel='LIV_away_goals'>

# %%
df_data_list = ['2013-2014']

# %%
df11= df[df.season.isin(df_data_list)]
df11
# Out:
#                  home_team          away_team  home_goals  away_goals result  \
# 2660             Liverpool         Stoke City         1.0         0.0      H
# 2661               Arsenal        Aston Villa         1.0         3.0      A
# 2662          Norwich City            Everton         2.0         2.0      D
# 2663            Sunderland             Fulham         0.0         1.0      A
# 2664  West Bromwich Albion        Southampton         0.0         1.0      A
# ...                    ...                ...         ...         ...    ...
# 3035          Norwich City            Arsenal         0.0         2.0      A
# 3036           Southampton  Manchester United         1.0         1.0      D
# 3037            Sunderland       Swansea City         1.0         3.0      A
# 3038     Tottenham Hotspur        Aston Villa         3.0         0.0      H
# 3039  West Bromwich Albion         Stoke City         1.0         2.0      A
#
#          season
# 2660  2013-2014
# ...

# %%
df11_data_list = ['Manchester City']

# %%
df12= df11[df11.home_team.isin(df11_data_list)]
df12
# Out:
#             home_team             away_team  home_goals  away_goals result  \
# 2669  Manchester City      Newcastle United         4.0         0.0      H
# 2681  Manchester City             Hull City         2.0         0.0      H
# 2709  Manchester City     Manchester United         4.0         1.0      H
# 2720  Manchester City               Everton         3.0         1.0      H
# 2753  Manchester City          Norwich City         7.0         0.0      H
# 2777  Manchester City     Tottenham Hotspur         6.0         0.0      H
# 2789  Manchester City          Swansea City         3.0         0.0      H
# 2810  Manchester City               Arsenal         6.0         3.0      H
# 2839  Manchester City             Liverpool         2.0         1.0      H
# 2843  Manchester City        Crystal Palace         1.0         0.0      H
# 2873  Manchester City          Cardiff City         4.0         2.0      H
# ...

# %%
df12.rename(columns = {'home_goals':'MANC_home_goals', 'away_goals':'MANC_away_goals'}, inplace=True)
df12
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5916\3531638557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.rename(columns = {'home_goals':'MANC_home_goals', 'away_goals':'MANC_away_goals'}, inplace=True)
#             home_team             away_team  MANC_home_goals  MANC_away_goals  \
# 2669  Manchester City      Newcastle United              4.0              0.0
# 2681  Manchester City             Hull City              2.0              0.0
# 2709  Manchester City     Manchester United              4.0              1.0
# 2720  Manchester City               Everton              3.0              1.0
# 2753  Manchester City          Norwich City              7.0              0.0
# 2777  Manchester City     Tottenham Hotspur              6.0              0.0
# ...

# %%
df13=df12.drop(['away_team', 'result'], axis = 1)
df13
# Out:
#             home_team  MANC_home_goals  MANC_away_goals     season
# 2669  Manchester City              4.0              0.0  2013-2014
# 2681  Manchester City              2.0              0.0  2013-2014
# 2709  Manchester City              4.0              1.0  2013-2014
# 2720  Manchester City              3.0              1.0  2013-2014
# 2753  Manchester City              7.0              0.0  2013-2014
# 2777  Manchester City              6.0              0.0  2013-2014
# 2789  Manchester City              3.0              0.0  2013-2014
# 2810  Manchester City              6.0              3.0  2013-2014
# 2839  Manchester City              2.0              1.0  2013-2014
# 2843  Manchester City              1.0              0.0  2013-2014
# 2873  Manchester City              4.0              2.0  2013-2014
# 2899  Manchester City              0.0              1.0  2013-2014
# 2921  Manchester City              1.0              0.0  2013-2014
# ...

# %%
df14= df[df.season.isin(df_data_list)]
df14
# Out:
#                  home_team          away_team  home_goals  away_goals result  \
# 2660             Liverpool         Stoke City         1.0         0.0      H
# 2661               Arsenal        Aston Villa         1.0         3.0      A
# 2662          Norwich City            Everton         2.0         2.0      D
# 2663            Sunderland             Fulham         0.0         1.0      A
# 2664  West Bromwich Albion        Southampton         0.0         1.0      A
# ...                    ...                ...         ...         ...    ...
# 3035          Norwich City            Arsenal         0.0         2.0      A
# 3036           Southampton  Manchester United         1.0         1.0      D
# 3037            Sunderland       Swansea City         1.0         3.0      A
# 3038     Tottenham Hotspur        Aston Villa         3.0         0.0      H
# 3039  West Bromwich Albion         Stoke City         1.0         2.0      A
#
#          season
# 2660  2013-2014
# ...

# %%
df14_data_list = ['Cardiff City']

# %%
df15= df14[df14.home_team.isin(df14_data_list)]
df15
# Out:
#          home_team             away_team  home_goals  away_goals result  \
# 2678  Cardiff City       Manchester City         3.0         2.0      H
# 2682  Cardiff City               Everton         0.0         0.0      D
# 2708  Cardiff City     Tottenham Hotspur         0.0         1.0      A
# 2721  Cardiff City      Newcastle United         1.0         2.0      A
# 2759  Cardiff City          Swansea City         1.0         0.0      H
# 2778  Cardiff City     Manchester United         2.0         2.0      D
# 2781  Cardiff City               Arsenal         0.0         3.0      A
# 2811  Cardiff City  West Bromwich Albion         1.0         0.0      H
# 2832  Cardiff City           Southampton         0.0         3.0      A
# 2845  Cardiff City            Sunderland         2.0         2.0      D
# 2861  Cardiff City       West Ham United         0.0         2.0      A
# 2892  Cardiff City          Norwich City         2.0         1.0      H
# ...

# %%
df15.rename(columns = {'home_goals':'CAD_home_goals', 'away_goals':'CAD_away_goals'}, inplace=True)
df15
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5916\2489895893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15.rename(columns = {'home_goals':'CAD_home_goals', 'away_goals':'CAD_away_goals'}, inplace=True)
#          home_team             away_team  CAD_home_goals  CAD_away_goals  \
# 2678  Cardiff City       Manchester City             3.0             2.0
# 2682  Cardiff City               Everton             0.0             0.0
# 2708  Cardiff City     Tottenham Hotspur             0.0             1.0
# 2721  Cardiff City      Newcastle United             1.0             2.0
# 2759  Cardiff City          Swansea City             1.0             0.0
# 2778  Cardiff City     Manchester United             2.0             2.0
# ...

# %%
df16=df15.drop(['away_team', 'result'], axis = 1)
df16
# Out:
#          home_team  CAD_home_goals  CAD_away_goals     season
# 2678  Cardiff City             3.0             2.0  2013-2014
# 2682  Cardiff City             0.0             0.0  2013-2014
# 2708  Cardiff City             0.0             1.0  2013-2014
# 2721  Cardiff City             1.0             2.0  2013-2014
# 2759  Cardiff City             1.0             0.0  2013-2014
# 2778  Cardiff City             2.0             2.0  2013-2014
# 2781  Cardiff City             0.0             3.0  2013-2014
# 2811  Cardiff City             1.0             0.0  2013-2014
# 2832  Cardiff City             0.0             3.0  2013-2014
# 2845  Cardiff City             2.0             2.0  2013-2014
# 2861  Cardiff City             0.0             2.0  2013-2014
# 2892  Cardiff City             2.0             1.0  2013-2014
# 2910  Cardiff City             0.0             0.0  2013-2014
# 2920  Cardiff City             0.0             4.0  2013-2014
# ...

# %%
df17 = df13.merge(df16, how='right')
df17
# Out:
#        home_team  MANC_home_goals  MANC_away_goals     season  CAD_home_goals  \
# 0   Cardiff City              NaN              NaN  2013-2014             3.0
# 1   Cardiff City              NaN              NaN  2013-2014             0.0
# 2   Cardiff City              NaN              NaN  2013-2014             0.0
# 3   Cardiff City              NaN              NaN  2013-2014             1.0
# 4   Cardiff City              NaN              NaN  2013-2014             1.0
# 5   Cardiff City              NaN              NaN  2013-2014             2.0
# 6   Cardiff City              NaN              NaN  2013-2014             0.0
# 7   Cardiff City              NaN              NaN  2013-2014             1.0
# 8   Cardiff City              NaN              NaN  2013-2014             0.0
# 9   Cardiff City              NaN              NaN  2013-2014             2.0
# 10  Cardiff City              NaN              NaN  2013-2014             0.0
# ...
